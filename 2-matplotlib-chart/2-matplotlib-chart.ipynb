# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.DataFrame(np.random.randint(-100,100, size=(100,4)), columns=list("ABCD"))
df
# Out:
#      A   B   C   D
# 0   -6  28 -81 -86
# 1   53 -54 -13   6
# 2  -97 -46 -57   6
# 3   97 -36  12 -99
# 4  -57  15  27  19
# ..  ..  ..  ..  ..
# 95 -78 -57  -9 -90
# 96 -51  75  45  76
# 97  78 -88  63 -49
# 98 -17 -53  34 -22
# 99  67  -1  10  -1
#
# [100 rows x 4 columns]

# %%
df['A'].plot()
# Out:
# <AxesSubplot:>

# %%
df2 = df.cumsum()
df2
# Out:
#       A    B    C    D
# 0    -6   28  -81  -86
# 1    47  -26  -94  -80
# 2   -50  -72 -151  -74
# 3    47 -108 -139 -173
# 4   -10  -93 -112 -154
# ..  ...  ...  ...  ...
# 95 -861 -459 -535 -361
# 96 -912 -384 -490 -285
# 97 -834 -472 -427 -334
# 98 -851 -525 -393 -356
# 99 -784 -526 -383 -357
#
# [100 rows x 4 columns]

# %%
df2.plot()
# Out:
# <AxesSubplot:>

# %%
df2['number'] = pd.Series(list(range(len(df2))))
df2
# Out:
#       A    B    C    D  number
# 0    -6   28  -81  -86       0
# 1    47  -26  -94  -80       1
# 2   -50  -72 -151  -74       2
# 3    47 -108 -139 -173       3
# 4   -10  -93 -112 -154       4
# ..  ...  ...  ...  ...     ...
# 95 -861 -459 -535 -361      95
# 96 -912 -384 -490 -285      96
# 97 -834 -472 -427 -334      97
# 98 -851 -525 -393 -356      98
# 99 -784 -526 -383 -357      99
#
# [100 rows x 5 columns]

# %%
df2.plot(x='number', y='B')
# Out:
# <AxesSubplot:xlabel='number'>

# %% [markdown]
# iloc -> index

# %%
df.iloc[5]
# Out:
# A   -79
# B   -87
# C   -15
# D   -22
# Name: 5, dtype: int32

# %%
plt.figure()
df.iloc[5].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df.head().plot.bar()
# Out:
# <AxesSubplot:>

# %%
df.head().plot.bar(stacked=True)
# Out:
# <AxesSubplot:>

# %%
df.head().plot.barh()
# Out:
# <AxesSubplot:>
