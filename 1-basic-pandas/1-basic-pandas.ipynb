# %% [markdown]
# Import Pandas Library

# %%
import pandas as pd

# %% [markdown]
# Import Dataset kedalam DataFrame

# %%
df = pd.read_csv("pokemon_data.csv")
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk
# 0                Bulbasaur    Grass  Poison  45      49       49       65  \
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Data Filtering

# %% [markdown]
# Get Nama Kolom di DataFrame

# %%
print(df.columns)
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk',
#        'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# Get Value dari Kolom Tertentu

# %%
print(df['Name'])
# Out:
# 0                  Bulbasaur
# 1                    Ivysaur
# 2                   Venusaur
# 3      VenusaurMega Venusaur
# 4                 Charmander
#                ...
# 795                  Diancie
# 796      DiancieMega Diancie
# 797      HoopaHoopa Confined
# 798       HoopaHoopa Unbound
# 799                Volcanion
# Name: Name, Length: 800, dtype: object

# %% [markdown]
# Get Value dari Index x ke y
# Misal [0:5] -> 0 - 4

# %%
print(df['Name'][0:5])
# Out:
# 0                Bulbasaur
# 1                  Ivysaur
# 2                 Venusaur
# 3    VenusaurMega Venusaur
# 4               Charmander
# Name: Name, dtype: object

# %% [markdown]
# Get Value dari banyak Kolom -> Array

# %%
print(df[['Name', 'Type 1', 'HP']])
# Out:
#                       Name   Type 1  HP
# 0                Bulbasaur    Grass  45
# 1                  Ivysaur    Grass  60
# 2                 Venusaur    Grass  80
# 3    VenusaurMega Venusaur    Grass  80
# 4               Charmander     Fire  39
# ..                     ...      ...  ..
# 795                Diancie     Rock  50
# 796    DiancieMega Diancie     Rock  50
# 797    HoopaHoopa Confined  Psychic  80
# 798     HoopaHoopa Unbound  Psychic  80
# 799              Volcanion     Fire  80
#
# [800 rows x 3 columns]

# %% [markdown]
# Get Info Semua Kolom, pada df berindex x

# %%
print(df.iloc[0])
# Out:
# Name          Bulbasaur
# Type 1            Grass
# Type 2           Poison
# HP                   45
# Attack               49
# Defense              49
# Sp. Atk              65
# Sp. Def              65
# Speed                45
# Generation            1
# Legendary         False
# Name: 0, dtype: object

# %% [markdown]
# Get Data dengan nama x, berdasarkan kondisi y

# %%
df.loc[df['Type 1'] == 'Grass']
# Out:
#                       Name Type 1    Type 2   HP  Attack  Defense  Sp. Atk
# 0                Bulbasaur  Grass    Poison   45      49       49       65  \
# 1                  Ivysaur  Grass    Poison   60      62       63       80
# 2                 Venusaur  Grass    Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass    Poison   80     100      123      122
# 48                  Oddish  Grass    Poison   45      50       55       75
# ..                     ...    ...       ...  ...     ...      ...      ...
# 718                Chespin  Grass       NaN   56      61       65       48
# 719              Quilladin  Grass       NaN   61      78       95       56
# 720             Chesnaught  Grass  Fighting   88     107      122       74
# 740                 Skiddo  Grass       NaN   66      65       48       62
# 741                 Gogoat  Grass       NaN  123     100       62       97
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Get Data dengan Multiple Condition -> using operator &

# %%
df.loc[(df['Type 1'] == 'Grass') & (df['Type 2'] == 'Poison')]
# Out:
#                       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk
# 0                Bulbasaur  Grass  Poison   45      49       49       65  \
# 1                  Ivysaur  Grass  Poison   60      62       63       80
# 2                 Venusaur  Grass  Poison   80      82       83      100
# 3    VenusaurMega Venusaur  Grass  Poison   80     100      123      122
# 48                  Oddish  Grass  Poison   45      50       55       75
# 49                   Gloom  Grass  Poison   60      65       70       85
# 50               Vileplume  Grass  Poison   75      80       85      110
# 75              Bellsprout  Grass  Poison   50      75       35       70
# 76              Weepinbell  Grass  Poison   65      90       50       85
# 77              Victreebel  Grass  Poison   80     105       65      100
# 344                Roselia  Grass  Poison   50      60       45      100
# 451                  Budew  Grass  Poison   40      30       35       50
# ...

# %% [markdown]
# Get Value dari kolom x, contains y

# %%
df.loc[df['Name'].str.contains('Mega')]
# Out:
#                           Name    Type 1    Type 2   HP  Attack  Defense
# 3        VenusaurMega Venusaur     Grass    Poison   80     100      123  \
# 7    CharizardMega Charizard X      Fire    Dragon   78     130      111
# 8    CharizardMega Charizard Y      Fire    Flying   78     104       78
# 12     BlastoiseMega Blastoise     Water       NaN   79     103      120
# 19       BeedrillMega Beedrill       Bug    Poison   65     150       40
# 23         PidgeotMega Pidgeot    Normal    Flying   83      80       80
# 71       AlakazamMega Alakazam   Psychic       NaN   55      50       65
# 87         SlowbroMega Slowbro     Water   Psychic   95      75      180
# 102          GengarMega Gengar     Ghost    Poison   60      65       80
# 124  KangaskhanMega Kangaskhan    Normal       NaN  105     125      100
# 137          PinsirMega Pinsir       Bug    Flying   65     155      120
# 141      GyaradosMega Gyarados     Water      Dark   95     155      109
# ...

# %% [markdown]
# Sort kolom x, default = asc, desc => Ascending=False

# %%
df.sort_values('Name')
# Out:
#                         Name   Type 1  Type 2   HP  Attack  Defense  Sp. Atk
# 794         Zygarde50% Forme   Dragon  Ground  108     100      121       81  \
# 695                 Zweilous     Dark  Dragon   72      85       70       65
# 46                     Zubat   Poison  Flying   40      45       35       30
# 631                    Zorua     Dark     NaN   40      65       40       80
# 632                  Zoroark     Dark     NaN   60     105       60      120
# ..                       ...      ...     ...  ...     ...      ...      ...
# 393          AbsolMega Absol     Dark     NaN   65     150       60      115
# 392                    Absol     Dark     NaN   65     130       60       75
# 68                      Abra  Psychic     NaN   25      20       15      105
# 511  AbomasnowMega Abomasnow    Grass     Ice   90     132      105      132
# 510                Abomasnow    Grass     Ice   90      92       75       92
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Buat Kolom baru x, hasil operasi y + z + n

# %%
df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df['Total']
# Out:
# 0      318
# 1      405
# 2      525
# 3      625
# 4      309
#       ...
# 795    600
# 796    700
# 797    600
# 798    680
# 799    600
# Name: Total, Length: 800, dtype: int64

# %% [markdown]
# Ubah value dari x ke y

# %%
df.loc[df['Type 1'] == 'Fire', 'Type 1'] = 'Flame'
df
# Out:
#                       Name   Type 1  Type 2  HP  Attack  Defense  Sp. Atk
# 0                Bulbasaur    Grass  Poison  45      49       49       65  \
# 1                  Ivysaur    Grass  Poison  60      62       63       80
# 2                 Venusaur    Grass  Poison  80      82       83      100
# 3    VenusaurMega Venusaur    Grass  Poison  80     100      123      122
# 4               Charmander     Fire     NaN  39      52       43       60
# ..                     ...      ...     ...  ..     ...      ...      ...
# 795                Diancie     Rock   Fairy  50     100      150      100
# 796    DiancieMega Diancie     Rock   Fairy  50     160      110      160
# 797    HoopaHoopa Confined  Psychic   Ghost  80     110       60      150
# 798     HoopaHoopa Unbound  Psychic    Dark  80     160       60      170
# 799              Volcanion     Fire   Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Export to csv, without index

# %%
df.to_csv('output.csv', index=False)
